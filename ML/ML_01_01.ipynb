# %%
import pandas as pd
import numpy as np

np.__version__, pd.__version__
# Out:
# ('1.16.4', '0.24.2')

# %%
# %reload_ext version_information

# %% [markdown]
# <h3>Einlesen der Daten</h3>

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.data'
cols = ['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','TGT']
boston = pd.read_csv(url, sep=' ', skipinitialspace=True, header=None, names=cols, index_col=False)

# %% [markdown]
# <h3>Darstellung als Pandas-DataFrame</h3>

# %%
boston
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0     0.00632  18.0   2.31     0  0.538  6.575   65.2  4.0900    1  296.0
# 1     0.02731   0.0   7.07     0  0.469  6.421   78.9  4.9671    2  242.0
# 2     0.02729   0.0   7.07     0  0.469  7.185   61.1  4.9671    2  242.0
# 3     0.03237   0.0   2.18     0  0.458  6.998   45.8  6.0622    3  222.0
# 4     0.06905   0.0   2.18     0  0.458  7.147   54.2  6.0622    3  222.0
# 5     0.02985   0.0   2.18     0  0.458  6.430   58.7  6.0622    3  222.0
# 6     0.08829  12.5   7.87     0  0.524  6.012   66.6  5.5605    5  311.0
# 7     0.14455  12.5   7.87     0  0.524  6.172   96.1  5.9505    5  311.0
# 8     0.21124  12.5   7.87     0  0.524  5.631  100.0  6.0821    5  311.0
# 9     0.17004  12.5   7.87     0  0.524  6.004   85.9  6.5921    5  311.0
# 10    0.22489  12.5   7.87     0  0.524  6.377   94.3  6.3467    5  311.0
# 11    0.11747  12.5   7.87     0  0.524  6.009   82.9  6.2267    5  311.0
# ...

# %% [markdown]
# Darstellung der ersten 5 Daten mit head()

# %%
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT   TGT
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Anzeigen der Reihen und Spalten

# %%
np.shape(boston)
# Out:
# (506, 14)

# %% [markdown]
# Spaltennamen

# %%
boston.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'TGT'],
#       dtype='object')

# %% [markdown]
# Datentypen der Variablen

# %%
boston.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# TGT        float64
# dtype: object

# %% [markdown]
# <h3>Aufbereitung des Datensatzes</h3>

# %% [markdown]
# NaN Überprüfung

# %%
boston.isna().any()
# Out:
# CRIM       False
# ZN         False
# INDUS      False
# CHAS       False
# NOX        False
# RM         False
# AGE        False
# DIS        False
# RAD        False
# TAX        False
# PTRATIO    False
# B          False
# LSTAT      False
# TGT        False
# dtype: bool

# %% [markdown]
# Entfernung aller Zeilen mit NaNs

# %%
boston = boston.dropna()
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT   TGT
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
boston.isnull().any()
# Out:
# CRIM       False
# ZN         False
# INDUS      False
# CHAS       False
# NOX        False
# RM         False
# AGE        False
# DIS        False
# RAD        False
# TAX        False
# PTRATIO    False
# B          False
# LSTAT      False
# TGT        False
# dtype: bool

# %% [markdown]
# Auf duplizierte Zeilen prüfen

# %%
boston.duplicated().any()
# Out:
# False

# %% [markdown]
# Falls True: Entfernen mit <I>DataFrame.drop_duplicates()</I>

# %% [markdown]
# <h3>Explorative Statistiken</h3>

# %% [markdown]
# Statistische Beschreibung der numerischen Variablen mit Dataframe.describe() (count: Anzahl Messungen, mean: Mittelwert, std: Standardabweichung, min: Minimum, 25%: 25-Perzentil, ...)

# %%
boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# Streumatrix für alle numerischen Variablen mit Pandas <I>scattermatrix()</I>:

# %%
plot = pd.plotting.scatter_matrix(boston, figsize=(14,14), marker='o');

# %% [markdown]
# <h2>Fragen zur Streumatrix</h2>

# %% [markdown]
# Welche der Variablen sind kategorisch?

# %% [markdown]
# CHAS und RAD, da sie nur eine geringe Anzahl von Werten annehmen

# %%
boston['CHAS'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
boston['RAD'].unique()
# Out:
# array([ 1,  2,  3,  5,  4,  8,  6,  7, 24], dtype=int64)

# %% [markdown]
# Welche der Variablen eignen sich gut zur Vorhersage des Hauspreises und
# warum?

# %% [markdown]
# Variablen, die mit dem Hauspreis korreliert sind. RM und LSTAT, da TGT der Hauspreis ist.

# %% [markdown]
# Welche dieser Variablen sind miteinander korreliert?

# %% [markdown]
# INDUS x NOX,
# INDUS x TAX,
# NOX x AGE,
# NOX x DIS,
# AGE x DIS,
# DIS x INDUS,
# RM x LSTAT,
# RM x TGT,
# LSTAT x TGT,

# %% [markdown]
# Welche sind daher Kandidaten,
# die man evtl. weglassen könnte?

# %% [markdown]
# INDUS, NOX, AGE

# %%
# %version_information numpy, pandas
# Out:
# Software versions
# Python 3.7.3 64bit [MSC v.1915 64 bit (AMD64)]
# IPython 7.6.1
# OS Windows 10 10.0.18362 SP0
# numpy 1.16.4
# pandas 0.24.2
# Mon Oct 14 10:37:09 2019 Mitteleuropäische Sommerzeit
